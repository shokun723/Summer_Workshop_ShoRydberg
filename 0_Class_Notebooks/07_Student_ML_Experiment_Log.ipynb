# %% [markdown]
# # Student Machine Learning Experiment Log
#
# Use this notebook to plan, track, and explain your mini-project. You do not need to write a lot of code here. The goal is to keep a clear record of your question, what you tried, what happened, and what decision you would make from the result.

# %% [markdown]
# ## 1. Team and Project Question
#
# **Team members:**
#
# **Project question:**
#
# Examples:
#
# - Can we classify device type from images?
# - Can we classify damaged versus not damaged devices?
# - Does RGB perform better than grayscale?
# - Does augmentation improve the result?
# - Can clustering highlight likely defect regions?

# %% [markdown]
# ## 2. Prediction Before Running the Model
#
# Before running the experiment, what do you think will happen?
#
# **Our prediction:**
#
# **Why we think this:**

# %% [markdown]
# ## 3. Dataset or Images Used
#
# **Which images or data did you use?**
#
# **What labels or groups did the data have?**
#
# **Anything unusual about the data?**
#
# Think about lighting, image angle, background, missing values, small sample size, or class imbalance.

# %% [markdown]
# ## 4. Method Used
#
# **Notebook used:**
#
# **Model or method used:**
#
# **Important setting changed:**
#
# Examples: image size, grayscale/RGB, target label, train/test split, model choice, number of clusters, augmentation amount.

# %%
# Optional: paste or write a small amount of code here if your instructor asks for it.
# Most of your model work can stay in the class notebooks.

# %% [markdown]
# ## 5. Result
#
# **Main result:**
#
# **Accuracy, score, or observation:**
#
# **Best plot, table, or image to show:**
#
# You can paste a screenshot or copy the important number from the class notebook.

# %% [markdown]
# ## 6. Mistake or Limitation
#
# Find one example where the model was wrong, uncertain, or possibly using the wrong clue.
#
# **What went wrong or looked questionable?**
#
# **Possible explanation:**
#
# **Why this matters:**

# %% [markdown]
# ## 7. Final Recommendation
#
# **Would you use this model or method?**
#
# **What would you use it for?**
#
# **What warning or limitation would you tell someone before they used it?**

# %% [markdown]
# ## 8. Short Presentation Checklist
#
# - Our question was clear.
# - We explained what data we used.
# - We showed one result.
# - We showed one limitation or mistake.
# - We made a recommendation based on evidence.
